# %%
# %matplotlib inline

import numpy as np
import cv2
import skimage.io as io
import matplotlib.pyplot as plt

# %%
img = cv2.imread('forged_image.png')
mask = cv2.imread('mask_forged_inverse.png',0)

# print (img.shape)
# print(mask.shape)

# dst = cv2.inpaint(img,mask,3,cv2.INPAINT_TELEA)
# dst = cv2.inpaint(img,mask,3,cv2.INPAINT_NS)

# cv2.imshow('dst',dst)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# plt.imshow(dst)
# plt.show()
# Out:
# (480, 640, 3)
# (480, 640)

# %%
from skimage.restoration import inpaint

image = io.imread('forged_image.png')
print(image.shape)
masks = io.imread('mask_forged_inverse.png', as_gray=True)
print(masks.shape)

image_result = inpaint.inpaint_biharmonic(image, masks, multichannel=True)

plt.axis('off')
plt.imshow(image_result)
plt.show()
io.imsave('inpainted.png', image_result)
# Out:
# (480, 640, 3)
# (480, 640)
# /home/akash/anaconda3/lib/python3.7/site-packages/skimage/util/dtype.py:141: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))

# %%
fig, axes = plt.subplots(ncols=2, nrows=2)
ax = axes.ravel()

ax[0].set_title('Original image')
ax[0].imshow(image_orig)

ax[1].set_title('Mask')
ax[1].imshow(mask, cmap=plt.cm.gray)
'forged_image.png'
ax[2].set_title('Defected image')
ax[2].imshow(image_defect)

ax[3].set_title('Inpainted image')
ax[3].imshow(image_result)

for a in ax:
    a.axis('off')

fig.tight_layout()
plt.show()
# Out:
# (200, 200, 3)
# (200, 200)
